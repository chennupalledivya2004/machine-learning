# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-23414dca-4779-4eae-9722-82316963c826" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23414dca-4779-4eae-9722-82316963c826">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data='lab1_datasets.xlsx'
df=pd.read_excel(data)
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
df.drop(df.iloc[:,5:18],inplace=True,axis=1)
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 18  Candy  Mango  Milk
# 0          NaN    1.0   55.0  18.0
# 1          NaN    NaN    NaN   NaN
# 2          NaN    NaN    NaN   NaN
# 3          NaN    NaN    NaN   NaN
# ...

# %%
df = df.drop(['Unnamed: 18'],axis = 1)

# %%
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  Candy  \
# 0      C_1           20             6                 2           386    1.0
# 1      C_2           16             3                 6           289    NaN
# 2      C_3           27             6                 2           393    NaN
# 3      C_4           19             1                 2           110    NaN
# 4      C_5           24             4                 2           280    NaN
# 5      C_6           22             1                 5           167    NaN
# 6      C_7           15             4                 2           271    NaN
# 7      C_8           18             4                 2           274    NaN
# 8      C_9           21             1                 4           148    NaN
# 9     C_10           16             2                 4           198    NaN
#
#    Mango  Milk
# 0   55.0  18.0
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN
# 5    NaN   NaN
# ...

# %%
df=df.drop(['Candy','Mango',	'Milk'],axis=1)

# %%
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198

# %%
a=df.iloc[:,1:4].values

# %%
a
# Out:
# array([[20,  6,  2],
#        [16,  3,  6],
#        [27,  6,  2],
#        [19,  1,  2],
#        [24,  4,  2],
#        [22,  1,  5],
#        [15,  4,  2],
#        [18,  4,  2],
#        [21,  1,  4],
#        [16,  2,  4]])

# %%
b=df.iloc[:,4].values

# %%
b
# Out:
# array([386, 289, 393, 110, 280, 167, 271, 274, 148, 198])

# %%
import numpy as np
rank = np.linalg.matrix_rank(a)
print(rank)
# Out:
# 3

# %%
c = np.linalg.pinv(a)
print(psuedo)
# Out:
# [[-0.01008596 -0.03124505  0.01013951  0.0290728   0.0182907   0.01161794
#   -0.00771348  0.00095458  0.01743623 -0.00542016]
#  [ 0.09059668  0.07263726  0.03172933 -0.09071908 -0.01893196 -0.06926996
#    0.05675464  0.03152577 -0.07641966  0.00357352]
#  [ 0.00299878  0.15874243 -0.05795468 -0.06609024 -0.06295043  0.03348017
#    0.01541831 -0.01070461  0.00029003  0.05938755]]

# %%
dimension = a.shape
print(dimension)
# Out:
# (10, 3)

# %%
vectors = a.shape[0]
print(vectors)
# Out:
# 10

# %%
costs = np.dot(psuedo, b)
print(costs)
# Out:
# [ 1. 55. 18.]

# %%
cost = np.dot(psuedo, b)
print(cost)
# Out:
# [ 1. 55. 18.]

# %%
df['Label'] = np.where(df['Payment (Rs)'] > 200, 'Rich', 'Poor')

# %%
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs) Label
# 0      C_1           20             6                 2           386  Rich
# 1      C_2           16             3                 6           289  Rich
# 2      C_3           27             6                 2           393  Rich
# 3      C_4           19             1                 2           110  Poor
# 4      C_5           24             4                 2           280  Rich
# 5      C_6           22             1                 5           167  Poor
# 6      C_7           15             4                 2           271  Rich
# 7      C_8           18             4                 2           274  Rich
# 8      C_9           21             1                 4           148  Poor
# 9     C_10           16             2                 4           198  Poor

# %%
x = df.iloc[:,1:5].values
x
# Out:
# array([[ 20,   6,   2, 386],
#        [ 16,   3,   6, 289],
#        [ 27,   6,   2, 393],
#        [ 19,   1,   2, 110],
#        [ 24,   4,   2, 280],
#        [ 22,   1,   5, 167],
#        [ 15,   4,   2, 271],
#        [ 18,   4,   2, 274],
#        [ 21,   1,   4, 148],
#        [ 16,   2,   4, 198]])

# %%
y = df.iloc[:,5].values
y
# Out:
# array(['Rich', 'Rich', 'Rich', 'Poor', 'Rich', 'Poor', 'Rich', 'Rich',
#        'Poor', 'Poor'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
classifier = LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict([[20,2,10,190]])
y_pred
# Out:
# array(['Poor'], dtype=object)
